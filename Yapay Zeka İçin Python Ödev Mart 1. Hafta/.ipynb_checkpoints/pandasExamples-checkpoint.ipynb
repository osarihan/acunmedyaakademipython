# %%
import pandas as pd

# %%
#json formatindaki dosyayi okur
#1
df = pd.read_json("Students_Grading_Dataset.json")
#bastan N kadar sutunu gosterir
#2
df.head(2)
# Out:
#   Student_ID First_Name Last_Name                    Email  Gender  Age  \
# 0      S1000       Omar  Williams  student0@university.com  Female   22
# 1      S1001      Maria     Brown  student1@university.com    Male   18
#
#     Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0  Engineering           52.29          55.03        57.82  ...
# 1  Engineering           97.27          97.23        45.80  ...
#
#    Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 0           85.90        56.09      F                   6.2
# 1           55.65        50.64      A                  19.0
#
#    Extracurricular_Activities Internet_Access_at_Home  Parent_Education_Level  \
# 0                          No                     Yes             High School
# 1                          No                     Yes                    None
#
#   Family_Income_Level Stress_Level (1-10) Sleep_Hours_per_Night
# 0              Medium                   5                   4.7
# ...

# %%
#data seti hakkinda bilgi verir
#3
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   First_Name                  5000 non-null   object
#  2   Last_Name                   5000 non-null   object
#  3   Email                       5000 non-null   object
#  4   Gender                      5000 non-null   object
#  5   Age                         5000 non-null   int64
#  6   Department                  5000 non-null   object
#  7   Attendance (%)              4484 non-null   float64
#  8   Midterm_Score               5000 non-null   float64
#  9   Final_Score                 5000 non-null   float64
#  10  Assignments_Avg             4483 non-null   float64
#  11  Quizzes_Avg                 5000 non-null   float64
#  12  Participation_Score         5000 non-null   float64
# ...

# %%
#yenilenen satirlari kontrol eder
#4
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
#csv turunde dosyayi okur
#5
df2 = pd.read_csv("Chocolate Sales.csv")
#6
# iki data frame'i alt alta ya da yan yana birlestirir
pd.concat([df, df2])
# Out:
#      Student_ID First_Name Last_Name                    Email  Gender   Age  \
# 0         S1000       Omar  Williams  student0@university.com  Female  22.0
# 1         S1001      Maria     Brown  student1@university.com    Male  18.0
# 2         S1002      Ahmed     Jones  student2@university.com    Male  24.0
# 3         S1003       Omar  Williams  student3@university.com  Female  24.0
# 4         S1004       John     Smith  student4@university.com  Female  23.0
# ...         ...        ...       ...                      ...     ...   ...
# 1089        NaN        NaN       NaN                      NaN     NaN   NaN
# 1090        NaN        NaN       NaN                      NaN     NaN   NaN
# 1091        NaN        NaN       NaN                      NaN     NaN   NaN
# 1092        NaN        NaN       NaN                      NaN     NaN   NaN
# 1093        NaN        NaN       NaN                      NaN     NaN   NaN
#
# ...

# %%
#yinelenen satirlari kaldirir
#7
df.drop_duplicates()
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female   22
# 1         S1001      Maria     Brown     student1@university.com    Male   18
# 2         S1002      Ahmed     Jones     student2@university.com    Male   24
# 3         S1003       Omar  Williams     student3@university.com  Female   24
# 4         S1004       John     Smith     student4@university.com  Female   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com    Male   19
# 4996      S5996       Emma     Brown  student4996@university.com    Male   19
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
# ...

# %%
#hucrelerin icinde eksik deger olup olmadigini kontrol eder
#8
df.isnull()
# Out:
#       Student_ID  First_Name  Last_Name  Email  Gender    Age  Department  \
# 0          False       False      False  False   False  False       False
# 1          False       False      False  False   False  False       False
# 2          False       False      False  False   False  False       False
# 3          False       False      False  False   False  False       False
# 4          False       False      False  False   False  False       False
# ...          ...         ...        ...    ...     ...    ...         ...
# 4995       False       False      False  False   False  False       False
# 4996       False       False      False  False   False  False       False
# 4997       False       False      False  False   False  False       False
# 4998       False       False      False  False   False  False       False
# 4999       False       False      False  False   False  False       False
#
#       Attendance (%)  Midterm_Score  Final_Score  ...  Projects_Score  \
# ...

# %%
#9
#Herhangi bir sütunda boş olan satırları siler.
df.dropna()
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female   22
# 2         S1002      Ahmed     Jones     student2@university.com    Male   24
# 3         S1003       Omar  Williams     student3@university.com  Female   24
# 4         S1004       John     Smith     student4@university.com  Female   23
# 7         S1007      Ahmed     Smith     student7@university.com    Male   19
# ...         ...        ...       ...                         ...     ...  ...
# 4989      S5989       Liam     Brown  student4989@university.com    Male   23
# 4993      S5993        Ali   Johnson  student4993@university.com  Female   22
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
# ...

# %%
#10
df3 = pd.DataFrame({"A": [1, 2 ,3], "B": [5, 6, 7]})
#DataFrame'i excel dosyasina yazar 
#openpyxl modulu yuklenmesi gerekir
df3.to_excel("asd.xlsx")

# %%
#11
#N. satiri index ile secer
df.iloc[3]
# Out:
# Student_ID                                      S1003
# First_Name                                       Omar
# Last_Name                                    Williams
# Email                         student3@university.com
# Gender                                         Female
# Age                                                24
# Department                                Mathematics
# Attendance (%)                                  95.15
# Midterm_Score                                   47.79
# Final_Score                                     80.63
# Assignments_Avg                                 66.06
# Quizzes_Avg                                     93.51
# Participation_Score                              6.54
# Projects_Score                                  92.12
# Total_Score                                     61.63
# Grade                                               A
# Study_Hours_per_Week                             24.8
# ...

# %%
#12
#kosula gore filtreler
df.loc[df["Last_Name"] == "Brown"]
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 1         S1001      Maria     Brown     student1@university.com    Male   18
# 5         S1005       Liam     Brown     student5@university.com    Male   21
# 30        S1030      Ahmed     Brown    student30@university.com  Female   22
# 45        S1045      Maria     Brown    student45@university.com    Male   21
# 52        S1052       John     Brown    student52@university.com  Female   19
# ...         ...        ...       ...                         ...     ...  ...
# 4987      S5987       John     Brown  student4987@university.com    Male   22
# 4989      S5989       Liam     Brown  student4989@university.com    Male   23
# 4996      S5996       Emma     Brown  student4996@university.com    Male   19
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
# ...
